# %%
from Functions.sorting_functions import *
import csv
from pathlib import Path

# %%
current_working_directory = Path.cwd()
directory = "JobLinks"
input_file = "Data_Scientist_job_links.csv"
output_path = current_working_directory / directory / input_file


links_list = []

with open(str(output_path), mode="r", encoding="utf-8") as file:
    reader = csv.reader(file)
    next(reader, None)  # Skip the header row if present
    
    # Append each link to the list
    for row in reader:
        if row:  # Check if row is not empty
            links_list.append(row[0])  # Access the first column (link)

print("Retrieved links from CSV:")
links_list[:5]
# Out:
# Retrieved links from CSV:
# ['https://www.apec.fr/candidat/recherche-emploi.html/emploi/detail-offre/175147280W?typesConvention=143684&typesConvention=143685&typesConvention=143686&typesConvention=143687&typesConvention=143706&motsCles=data%20scientist&niveauxExperience=101881&page=0&selectedIndex=0',
#  'https://www.apec.fr/candidat/recherche-emploi.html/emploi/detail-offre/175171031W?typesConvention=143684&typesConvention=143685&typesConvention=143686&typesConvention=143687&typesConvention=143706&motsCles=data%20scientist&niveauxExperience=101881&page=0&selectedIndex=1',
#  'https://www.apec.fr/candidat/recherche-emploi.html/emploi/detail-offre/174685644W?typesConvention=143684&typesConvention=143685&typesConvention=143686&typesConvention=143687&typesConvention=143706&motsCles=data%20scientist&niveauxExperience=101881&page=0&selectedIndex=2',
#  'https://www.apec.fr/candidat/recherche-emploi.html/emploi/detail-offre/175035943W?typesConvention=143684&typesConvention=143685&typesConvention=143686&typesConvention=143687&typesConvention=143706&motsCles=data%20scientist&niveauxExperience=101881&page=0&selectedIndex=3',
#  'https://www.apec.fr/candidat/recherche-emploi.html/emploi/detail-offre/175218313W?typesConvention=143684&typesConvention=143685&typesConvention=143686&typesConvention=143687&typesConvention=143706&motsCles=data%20scientist&niveauxExperience=101881&page=0&selectedIndex=4']

# %%
login_file_path = "~/Documents/GitHub/login.txt"
usr, password = read_login_credentials(login_file_path)
cv_path = '/home/ocr8n/Documents/CV_Aziz_ISC.pdf'
message = ''

# %%
links_counter = 0
submitted_counter = 0
applied_counter = 0
external_links_counter = 0
not_available_counter = 0

external_links_list = []

for link in links_list:
    links_counter += 1
    print('________________________________________________\n')
    print(f'Link number : {links_counter}\n')
    print('\n First step, Can I apply easily?\n')
    driver,note = check_easy_apply(link)

    match note:
            case 1:
                print('Yes !! Easy apply found\n')
                print('connecting ....\n')
                driver = apec_connect(driver, usr, password)
                print('connected !! \n')

                if not already_applied(driver):
                    fill_and_submit(driver, cv_path, message)
                    time.sleep(2)
                    driver.quit()
                    print("Submitted, everything fine")
                    submitted_counter += 1

                else:
                    driver.quit()
                    print('Great !! I already applied to this job.')                    
                    applied_counter += 1

            case 2:
                print('Unfortunately, External website link  :(')                
                driver.quit()
                external_links_counter += 1
                external_links_list.append(link)

            case 3:
                print('probably the announcement is no longer available')
                driver.quit()
                not_available_counter += 1
# Out:
# ________________________________________________
#
# Link number : 1
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Great !! I already applied to this job.
# ________________________________________________
#
# Link number : 2
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Great !! I already applied to this job.
# ________________________________________________
#
# Link number : 3
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Great !! I already applied to this job.
# ________________________________________________
#
# Link number : 4
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Great !! I already applied to this job.
# ________________________________________________
#
# Link number : 5
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 6
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Great !! I already applied to this job.
# ________________________________________________
#
# Link number : 7
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 8
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 9
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Great !! I already applied to this job.
# ________________________________________________
#
# Link number : 10
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Great !! I already applied to this job.
# ________________________________________________
#
# Link number : 11
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 12
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 13
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 14
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 15
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 16
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 17
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 18
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 19
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 20
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 21
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 22
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 23
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 24
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 25
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 26
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 27
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 28
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 29
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 30
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 31
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 32
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 33
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 34
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 35
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 36
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 37
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Error during submitting process: Message:
#
# Submitted, everything fine
# ________________________________________________
#
# Link number : 38
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 39
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 40
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 41
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 42
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 43
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 44
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 45
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 46
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 47
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 48
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 49
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 50
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 51
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 52
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 53
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 54
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 55
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 56
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 57
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 58
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 59
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 60
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 61
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 62
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 63
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 64
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 65
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 66
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 67
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 68
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 69
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 70
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 71
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 72
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 73
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 74
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 75
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 76
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 77
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 78
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 79
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 80
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 81
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 82
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 83
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 84
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 85
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 86
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 87
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 88
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 89
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 90
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 91
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 92
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 93
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 94
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 95
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 96
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 97
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 98
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 99
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Error during submitting process: Message:
#
# Submitted, everything fine
# ________________________________________________
#
# Link number : 100
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 101
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 102
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 103
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 104
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 105
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 106
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 107
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 108
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 109
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 110
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 111
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 112
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 113
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 114
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 115
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 116
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 117
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 118
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Error during submitting process: Message:
#
# Submitted, everything fine
# ________________________________________________
#
# Link number : 119
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 120
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 121
#
#
#  First step, Can I apply easily?
#
# Yes !! Easy apply found
#
# connecting ....
#
# connected !!
#
# Application possibility.
# Submitted, everything fine
# ________________________________________________
#
# Link number : 122
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 123
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(
# ________________________________________________
#
# Link number : 124
#
#
#  First step, Can I apply easily?
#
# Unfortunately, External website link  :(

# %%
# Summary of the results
print('\n\nSummary of Application Process:')
print('--------------------------------')
print(f'Total links processed: {links_counter}')
print(f'Successfully submitted applications: {submitted_counter}')
print(f'Already applied: {applied_counter}')
print(f'External website links: {external_links_counter}')
print(f'Announcements no longer available: {not_available_counter}')
# Out:
# Summary of Application Process:
# --------------------------------
# Total links processed: 124
# Successfully submitted applications: 30
# Already applied: 7
# External website links: 87
# Announcements no longer available: 0

# %%
driver.quit()
